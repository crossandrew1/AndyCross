# %%
from keras_segmentation.predict import model_from_checkpoint_path
from keras_segmentation.predict import predict
from shutil import copyfile

model = model_from_checkpoint_path("/Users/andrewcross/Desktop/MHFDDrone Data/EroPsp100_20210503/ero/pred/erosion_20210405")
import glob
lat_array=[]
long_array=[]
location=[]
for i in glob.glob("/Volumes/Internal SSD/DF_202100409_RockCreek/*.JPG"):
    name=i.split("/")
    name=name[-1]
    name=name.split(".")
    name=name[0]
    pr,vals,counts=predict(model=model, inp=i,out_fname="/Users/andrewcross/Desktop/MHFDDrone Data/EroPsp100_20210503/ero/pred/out2/"+str(name)+".jpg",overlay_img=True)
    if len(vals) > 1:
        for i in range(0,len(vals)):
            if vals[i] == 1 and counts[i] > 2500:
                copyfile("/Volumes/Internal SSD/DF_202100409_RockCreek/"+str(name)+".JPG", "/Users/andrewcross/Desktop/MHFDDrone Data/EroPsp100_20210503/ero/pred/out2/")
# Out:
# ('loaded weights ', '/Users/andrewcross/Desktop/MHFDDrone Data/EroPsp100_20210503/ero/pred/erosion_20210405.17')

# %%
from keras_segmentation.predict import model_from_checkpoint_path
from keras_segmentation.predict import predict
from shutil import copyfile

model = model_from_checkpoint_path("/Users/andrewcross/Desktop/MHFDDrone Data/Mannings_20210505/Mannings_20210505/trained/predict/Mannings_20210506")
import glob
lat_array=[]
long_array=[]
location=[]
for i in glob.glob("/Volumes/Internal SSD/DF_202100409_RockCreek/*.JPG"):
    name=i.split("/")
    name=name[-1]
    name=name.split(".")
    name=name[0]
    pr,vals,counts=predict(model=model, inp=i,out_fname="/Users/andrewcross/Desktop/MHFDDrone Data/Mannings_20210505/Mannings_20210505/trained/out/"+str(name)+".jpg",overlay_img=True,class_names=["bg","Short Grass","High Grass","Light Bush","Dense Bush","Trees"],show_legends=False)
# Out:
# ('loaded weights ', '/Users/andrewcross/Desktop/MHFDDrone Data/Mannings_20210505/Mannings_20210505/trained/predict/Mannings_20210506.31')

# %%
import cv2
import numpy as np
im = cv2.imread("/Users/andrewcross/Desktop/MHFDDrone Data/Mannings_20210505/Mannings_20210505/trained/out/DJI_0057.jpg")
shape=np.shape(im)
b,g,r = cv2.split(im)

for i in range(0,shape[0]):
    for j in range(0,shape[1]):
        
        print(r[i,j],g[i,j],b[i,j])
# Out:
# (255, 255, 255)
# (255, 255, 255)
# (252, 252, 252)
# (255, 255, 255)
# (254, 254, 254)
# (255, 255, 255)
# (255, 255, 255)
# (254, 254, 254)
# (255, 255, 255)
# (252, 252, 252)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (254, 254, 254)
# (255, 255, 255)
# (254, 254, 254)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# ...

# %%
# Out:
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
