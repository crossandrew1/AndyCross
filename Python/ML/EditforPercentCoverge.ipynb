# %%
import glob
import numpy as np
import cv2


for image in glob.glob("/Users/andrewcross/Downloads/PercentCoverage/*.png"):
    im = cv2.imread(image)
    height, width, channels = np.shape(im)
    for i in range(0,height):
        for j in range(0,width):
            for p in range(0,channels):
                if im[i,j,p] == 7 or im[i,j,p] ==13:
                    im[i,j,p] = 1
                elif im[i,j,p] == 8 or im[i,j,p] ==14 or im[i,j,p] ==2:
                    im[i,j,p]=1
                elif im[i,j,p]==9 or im[i,j,p] ==15 or im[i,j,p] ==3:
                    im[i,j,p]=2
                elif im[i,j,p]==10 or im[i,j,p] ==16 or im[i,j,p] ==4:
                    im[i,j,p]=2
                elif im[i,j,p]==11 or im[i,j,p] ==17 or im[i,j,p] ==5:
                    im[i,j,p]=3
                elif im[i,j,p]==12 or im[i,j,p] ==18 or im[i,j,p] ==6:
                    im[i,j,p]=2
    name=image.split("/")
    name=name[-1]
    print(name)
    cv2.imwrite("/Users/andrewcross/Desktop/MHFDDrone Data/PercentCoverageTrain/EditedforBushesLabels/"+str(name),im)
# Out:
# OakGulch0164_4540.png
# OakGulch0164_1203.png
# MarceyGulch0160_3373.png
# SpringGulch0176_2559.png
# MarceyGulch0160_2642.png
# BigDryCreek0171_1313.png
# SpringGulch0176_1509.png
# BigDryCreek0171_1048.png
# SpringGulch0176_3535.png
# MarceyGulch0160_529.png
# BigDryCreek0171_1466.png
# SpringGulch0176_6498.png
# SpringGulch0176_3537.png
# OakGulch0164_4655.png
# OakGulch0164_1102.png
# SpringGulch0176_5727.png
# MarceyGulch0160_2756.png
# BigDryCreek0171_3770.png
# OakGulch0164_810.png
# OakGulch0164_1921.png
# SpringGulch0176_5678.png
# SpringGulch0176_28.png
# OakGulch0164_4643.png
# MarceyGulch0160_2590.png
# OakGulch0164_1065.png
# MarceyGulch0160_5363.png
# BigDryCreek0171_1000.png
# SpringGulch0176_951.png
# OakGulch0164_1715.png
# SpringGulch0176_992.png
# OakGulch0164_1067.png
# SpringGulch0176_2529.png
# OakGulch0164_1891.png
# MarceyGulch0160_2776.png
# MarceyGulch0160_7021.png
# BigDryCreek0171_1568.png
# BigDryCreek0171_3960.png
# BigDryCreek0171_1191.png
# ...

# %%
import glob
import numpy as np
import cv2


for image in glob.glob("/Users/andrewcross/Downloads/PercentCoverage/*.png"):
    im = cv2.imread(image)
    height, width, channels = np.shape(im)
    for i in range(0,height):
        for j in range(0,width):
            for p in range(0,channels):
                if im[i,j,p] == 7 or im[i,j,p] ==13:
                    im[i,j,p] = 1
                elif im[i,j,p] == 8 or im[i,j,p] ==14 or im[i,j,p] ==2:
                    im[i,j,p]=1
                elif im[i,j,p]==9 or im[i,j,p] ==15 or im[i,j,p] ==3:
                    im[i,j,p]=2
                elif im[i,j,p]==10 or im[i,j,p] ==16 or im[i,j,p] ==4:
                    im[i,j,p]=2
                elif im[i,j,p]==11 or im[i,j,p] ==17 or im[i,j,p] ==5:
                    im[i,j,p]=3
                elif im[i,j,p]==12 or im[i,j,p] ==18 or im[i,j,p] ==6:
                    im[i,j,p]=2
    name=image.split("/")
    name=name[-1]
    print(name)
    cv2.imwrite("/Users/andrewcross/Desktop/MHFDDrone Data/PercentCoverageTrain/EditedforBushesLabels/"+str(name),im)

# %%
import glob
import cv2
import numpy as np
problem=[]
fine=[]
for i in glob.glob("/Users/andrewcross/Desktop/Cdot/SedFenceFUll/*.png"):
    im = cv2.imread(i)
    vals, counts = np.unique(im,return_counts=True)
    for j in vals:
        if j == 1:
            fine.append(i)
        if j == 3:
            problem.append(i)


print(len(fine))

print(len(problem))
# Out:
# 90
# 93

# %%
im=[]
for i in glob.glob("/Users/andrewcross/Desktop/DroneFlight_20201901/ManningsUpload/LARGER/*.png"):
    thi=i.split("/")
    thi=thi[-1]
    im.append(thi)

# %%
import shutil
for g in glob.glob("/Users/andrewcross/Desktop/MHFDDrone Data/PercentCoverageTrain/EditedforBushesLabels/*.png"):
    i = g.split("/")
    i=i[-1]
    if i in im:
        shutil.copy("/Users/andrewcross/Desktop/DroneFlight_20201901/ManningsUpload/LARGER/"+str(i),"/Users/andrewcross/Desktop/MHFDDrone Data/PercentCoverageTrain/BushesImages")
