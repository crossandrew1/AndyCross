# %%
import cv2
import numpy as np 
import glob

for j in glob.glob("/Volumes/Internal SSD/DroneFlight_20210329_BDC/*.MOV"):
    print(j)
    name=j.split("/")
    name=name[-1]
    name=name.split(".")
    name=name[0]
    vidcap = cv2.VideoCapture(j)
    success,image = vidcap.read()
    count = 0
    while success:
        success,image = vidcap.read()
        if count % 60 == 0:
            img = cv2.resize(image,(1152,768))  
            cv2.imwrite("/Volumes/Internal SSD/DroneFlight_20210329_BDC/imagesAnno/drone_"+str(name)+"_BDC_%d.png" % count, img)     # save frame as JPEG file      
            print(count)
        count += 1
# Out:
# /Volumes/Internal SSD/DroneFlight_20210329_BDC/DJI_0001.MOV
# 0
# 60
# 120
# 180
# 240
# 300
# 360
# 420
# 480
# 540
# 600
# 660
# 720
# 780
# 840
# 900
# 960
# 1020
# 1080
# 1140
# 1200
# 1260
# 1320
# 1380
# 1440
# 1500
# 1560
# 1620
# 1680
# 1740
# 1800
# 1860
# 1920
# 1980
# 2040
# 2100
# 2160
# 2220
# 2280
# 2340
# 2400
# 2460
# 2520
# 2580
# 2640
# 2700
# 2760
# 2820
# 2880
# 2940
# 3000
# /Volumes/Internal SSD/DroneFlight_20210329_BDC/DJI_0002.MOV
# 0
# 60
# 120
# 180
# 240
# 300
# 360
# 420
# 480
# 540
# 600
# 660
# 720
# 780
# 840
# 900
# 960
# 1020
# 1080
# 1140
# 1200
# 1260
# 1320
# 1380
# 1440
# 1500
# 1560
# 1620
# /Volumes/Internal SSD/DroneFlight_20210329_BDC/DJI_0003.MOV
# 0
# 60
# 120
# 180
# 240
# 300
# 360
# 420
# 480
# 540
# 600
# 660
# 720
# 780
# 840
# 900
# 960
# 1020
# 1080
# 1140
# 1200
# 1260
# 1320
# 1380
# 1440
# 1500
# 1560
# 1620
# 1680
# 1740
# 1800
# 1860
# 1920
# 1980
# 2040
# 2100
# 2160
# 2220
# 2280
# 2340
# 2400
# 2460
# 2520
# 2580
# 2640
# ...

# %%
import pysrt as ps

dat=ps.open("/Users/andrewcross/Desktop/DroneFlight_20201901/BigDryCreek/DJI_0170.SRT")
count=50
ls=str(dat[count])
lat_ind=ls.index("latitude")
lon_ind=ls.index("longitude")

lat=ls[int(lat_ind):int(lat_ind)+19]
lon=ls[int(lon_ind):int(lon_ind)+22]
print(lat,lon)
# Out:
# latitude: 39.530901 longitude: -104.909519

# %%
import numpy as np
s = np.random.uniform(0,4500,20)
import shutil
import glob
for file in glob.glob("/Users/andrewcross/Desktop/DroneFlight_20201901/Images/*.png"):
    string = file.split("_")
    string=string[-1]
    for i in s:
        int_val = str(np.round(i))
        int_val = int_val.split(".")
        check = int_val[0]+str(".png")
        if check == string:
            print("move")
            shutil.copy(file, "/Users/andrewcross/Desktop/Erosion/")
# Out:
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move
# move

# %%
import os

files = os.listdir("/Users/andrewcross/Desktop/Erosion/")
files_anno = os.listdir("/Users/andrewcross/Desktop/Erosion_Annotations/")
#print(files_anno)
for i in files_anno:
    for j in files:
        if j == i:
            shutil.copy("/Users/andrewcross/Desktop/Erosion/"+str(j), "/Users/andrewcross/Desktop/Erosion_Images/")

# %%
from keras_segmentation.models.model_utils import transfer_weights
from keras_segmentation.pretrained import pspnet_50_ADE_20K
from keras_segmentation.models.pspnet import pspnet_50

pretrained_model = pspnet_50_ADE_20K()

new_model = pspnet_50( n_classes=2 )

transfer_weights( pretrained_model , new_model  ) # transfer weights from pre-trained model to your model

new_model.train(
    train_images =  "Erosion_Images/",
    train_annotations = "Erosion_Annotations/",
    checkpoints_path = "Erosion" , epochs=20
)
# Out:
# Using TensorFlow backend.
# ...
# WARNING:tensorflow:From /Users/andrewcross/anaconda3/envs/keras_seg/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/andrewcross/anaconda3/envs/keras_seg/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:349: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/andrewcross/anaconda3/envs/keras_seg/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:3147: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/andrewcross/anaconda3/envs/keras_seg/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:3014: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...
